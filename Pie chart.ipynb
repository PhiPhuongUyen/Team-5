# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
from pandasql import sqldf
import numpy as np

# %%
url = "https://raw.githubusercontent.com/Mao2003/Mao2003/main/results.csv"
df= pd.read_csv(url,encoding = 'unicode_escape')
pysqldf = lambda q: sqldf(q, globals())

# %%
df3=pysqldf("SELECT date, COUNT(tournament) AS [cnt_t], tournament\
             FROM df\
             WHERE date>2023\
             GROUP BY tournament\
            ORDER BY [cnt_t] DESC")
print(df3)
# Out:
#           date  cnt_t                               tournament
# 0   2023-01-08    177                                 Friendly
# 1   2023-03-23    138                  UEFA Euro qualification
# 2   2023-03-23     72                  CONCACAF Nations League
# 3   2023-03-22     65     African Cup of Nations qualification
# 4   2023-06-24     31                                 Gold Cup
# 5   2023-06-21     15                                 SAFF Cup
# 6   2023-01-06     15                                 Gulf Cup
# 7   2023-09-07     10             FIFA World Cup qualification
# 8   2023-06-11     10                         CAFA Nations Cup
# 9   2023-06-16      9                   Gold Cup qualification
# 10  2023-03-22      7                    Tri Nation Tournament
# 11  2023-06-11      5               Mauritius Four Nations Cup
# 12  2023-06-17      5  CONIFA World Football Cup qualification
# 13  2023-06-14      4                      UEFA Nations League
# 14  2023-09-07      4                               King's Cup
# 15  2023-08-04      4                          CONIFA Asia Cup

# %%
import matplotlib.pyplot as plt

labels = df3['tournament']
sizes = df3['cnt_t']

plt.pie(sizes, autopct='%1.1f%%', pctdistance=1.15)
plt.axis('equal')
plt.title('Odds of matches by tournament')

plt.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('pie_chart.png')

plt.show()
